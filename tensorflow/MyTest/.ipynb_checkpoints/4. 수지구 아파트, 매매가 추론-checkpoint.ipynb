# %%
# -*- coding: utf-8 -*-
import pickle
import tensorflow as tf
import numpy as np
# import sklearn

from bokeh.plotting import figure, show, output_notebook, output_file
from bokeh.models import HoverTool, ColumnDataSource
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="dfba7aa9-4574-4543-b7ca-9ebee0ab3cb9">Loading BokehJS ...</span>
#     </div>

# %%
estate_file = open('./data/estate_suji.dat','rb')
estate_price = pickle.load(estate_file)
estate_price_cnt = len(estate_price)
chart_name = "# 170310, 수지구 아파트 매매가 {0}건 (NAVER)".format(str(estate_price_cnt))

before_x = []
before_y = []

names = []
labels = []

print(estate_price[0])

for item in estate_price:
    p = item['price']/10000
    before_x.append(item['space'])
    before_y.append(p)
    names.append(item['name'])
    labels.append("{}평/{}억".format(item['space'], p))

# sklearn.preprocessing.minmax_scale()

# before_x = np.array(before_x)
# before_y = np.array(before_y)
# print(before_x.shape)
# print(before_y.shape)
# Out:
# {'space': 37, 'name': '만현마을5단지현대아이파크7', 'price': 37000}

# %%
# tf.Variable: 그래프를 계산하면서 최적화 할 변수들입니다. 
# 이 값이 바로 신경망을 좌우하는 값들입니다.

# tf.random_uniform: 균일 한 분포에서 임의의 값을 출력합니다.
# tf.random_uniform(shape, minval=0, maxval=None, dtype=tf.float32, seed=None, name=None)
X = tf.placeholder(tf.float32, name='area')
Y = tf.placeholder(tf.float32, name='price')

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0), name='Weight')
# W = tf.get_variable('w', [1], initializer=tf.contrib.layers.xavier_initializer())
B = tf.Variable(tf.random_uniform([1], -1.0, 1.0), name='b')

# %%
hypothesis = W*X+B

# 손실 함수를 작성합니다.
# mean(h - Y)^2 : 예측값과 실제값의 거리를 비용(손실) 함수로 정합니다.
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 텐서플로우에 기본적으로 포함되어 있는 함수를 이용해 경사 하강법 최적화를 수행합니다.
train = tf.train.GradientDescentOptimizer(learning_rate=0.0000005).minimize(cost)
# train = tf.train.AdamOptimizer(0.1).minimize(cost)

# %%
history = {
    'cost' : [],
    'hypothesis' : [],
    'weight': [],
}

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(5000):
    # sess.run 을 통해 train_op 와 cost 그래프를 계산합니다.
    # 이 때, 가설 수식에 넣어야 할 실제값을 feed_dict 을 통해 전달합니다.
    _, c, w, b = sess.run([train, cost, W, B], feed_dict={X: before_x, Y: before_y})

    if step % 100 == 0:
        history['cost'].append(c)
        history['weight'].append(w)
        
        print("step: {0}, cost: {1}, w: {2}, b: {3}".format(step, c, w, b))
# Out:
# step: 0, cost: 1595.6298828125, w: [-0.75183094], b: [-0.67593205]
# step: 100, cost: 1.1449946165084839, w: [ 0.0998046], b: [ 0.31039745]
# step: 200, cost: 1.047865867614746, w: [ 0.09885057], b: [ 0.53830433]
# step: 300, cost: 0.9862913489341736, w: [ 0.09303437], b: [ 0.78805572]
# step: 400, cost: 0.9381390810012817, w: [ 0.08734025], b: [ 1.03156734]
# step: 500, cost: 0.9050227403640747, w: [ 0.08224252], b: [ 1.24957907]
# step: 600, cost: 0.884555459022522, w: [ 0.07796982], b: [ 1.43230736]
# step: 700, cost: 0.8730690479278564, w: [ 0.07458524], b: [ 1.57705402]
# step: 800, cost: 0.867183268070221, w: [ 0.07203864], b: [ 1.68596339]
# step: 900, cost: 0.864423930644989, w: [ 0.07021367], b: [ 1.76401055]
# step: 1000, cost: 0.8632395267486572, w: [ 0.06896638], b: [ 1.81735265]
# step: 1100, cost: 0.8627743721008301, w: [ 0.06815305], b: [ 1.85213602]
# step: 1200, cost: 0.8626068830490112, w: [ 0.06764711], b: [ 1.87377322]
# step: 1300, cost: 0.8625521659851074, w: [ 0.06734712], b: [ 1.88660288]
# step: 1400, cost: 0.8625364303588867, w: [ 0.06717777], b: [ 1.89384568]
# step: 1500, cost: 0.8625314831733704, w: [ 0.06708685], b: [ 1.89773345]
# step: 1600, cost: 0.862530529499054, w: [ 0.06704054], b: [ 1.89971411]
# step: 1700, cost: 0.8625301718711853, w: [ 0.06701819], b: [ 1.90066993]
# step: 1800, cost: 0.8625298142433167, w: [ 0.06700801], b: [ 1.90110564]
# step: 1900, cost: 0.8625301718711853, w: [ 0.06700363], b: [ 1.9012928]
# step: 2000, cost: 0.8625298738479614, w: [ 0.06700186], b: [ 1.90136826]
# step: 2100, cost: 0.862530529499054, w: [ 0.0670012], b: [ 1.90139663]
# step: 2200, cost: 0.8625300526618958, w: [ 0.06700096], b: [ 1.90140724]
# step: 2300, cost: 0.8625300526618958, w: [ 0.06700096], b: [ 1.90140724]
# step: 2400, cost: 0.8625300526618958, w: [ 0.06700095], b: [ 1.90140724]
# step: 2500, cost: 0.8625302314758301, w: [ 0.06700093], b: [ 1.9014076]
# step: 2600, cost: 0.862529993057251, w: [ 0.06700093], b: [ 1.90140796]
# step: 2700, cost: 0.8625300526618958, w: [ 0.06700093], b: [ 1.90140808]
# step: 2800, cost: 0.8625301718711853, w: [ 0.06700093], b: [ 1.9014082]
# step: 2900, cost: 0.8625301718711853, w: [ 0.06700093], b: [ 1.9014082]
# step: 3000, cost: 0.8625300526618958, w: [ 0.06700092], b: [ 1.90140867]
# step: 3100, cost: 0.8625300526618958, w: [ 0.06700092], b: [ 1.90140867]
# step: 3200, cost: 0.8625300526618958, w: [ 0.06700092], b: [ 1.90140879]
# step: 3300, cost: 0.8625300526618958, w: [ 0.06700091], b: [ 1.90140879]
# step: 3400, cost: 0.8625302314758301, w: [ 0.0670009], b: [ 1.90140891]
# step: 3500, cost: 0.8625300526618958, w: [ 0.0670009], b: [ 1.90140927]
# step: 3600, cost: 0.8625300526618958, w: [ 0.0670009], b: [ 1.90140927]
# step: 3700, cost: 0.8625300526618958, w: [ 0.0670009], b: [ 1.90140927]
# step: 3800, cost: 0.8625300526618958, w: [ 0.0670009], b: [ 1.90140927]
# step: 3900, cost: 0.8625300526618958, w: [ 0.0670009], b: [ 1.90140975]
# step: 4000, cost: 0.8625300526618958, w: [ 0.06700089], b: [ 1.90140975]
# step: 4100, cost: 0.8625300526618958, w: [ 0.0670009], b: [ 1.90140975]
# step: 4200, cost: 0.8625300526618958, w: [ 0.06700089], b: [ 1.90140975]
# step: 4300, cost: 0.8625298738479614, w: [ 0.06700089], b: [ 1.90140986]
# step: 4400, cost: 0.8625300526618958, w: [ 0.06700087], b: [ 1.90141022]
# step: 4500, cost: 0.8625300526618958, w: [ 0.06700087], b: [ 1.90141022]
# step: 4600, cost: 0.862529993057251, w: [ 0.06700088], b: [ 1.90141022]
# step: 4700, cost: 0.8625300526618958, w: [ 0.06700089], b: [ 1.90141022]
# step: 4800, cost: 0.8625300526618958, w: [ 0.06700088], b: [ 1.90141022]
# step: 4900, cost: 0.8625298738479614, w: [ 0.06700088], b: [ 1.90141022]

# %%
# [] 데이터셋 분포 및
source = ColumnDataSource(
        data = dict(
            x = before_x,
            y = before_y,
            names=names,
            detail=labels,
        )
    )

hover = HoverTool(
        tooltips=[
            ("아파트", "@names"),
            ("매매가", "@detail"),
        ]
    )
TOOLS = "pan,wheel_zoom,box_zoom,reset,resize"

p = figure(plot_width=900, plot_height=400, tools=[TOOLS,hover], title=chart_name)
p.scatter('x', 'y', size=6, source=source, alpha=0.4, fill_color="red", line_color="#ff9900")
p.circle(x=before_x, y=(sess.run(W)*before_x+sess.run(B)), line_width=3, line_cap="round")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d7accdd9-c51c-44dc-8be4-eb8f6c40af9b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d7accdd9-c51c-44dc-8be4-eb8f6c40af9b").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d7accdd9-c51c-44dc-8be4-eb8f6c40af9b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd7accdd9-c51c-44dc-8be4-eb8f6c40af9b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"26486a3e-0dda-4b24-ab8e-ca718ca82a36":{"roots":{"references":[{"attributes":{"formatter":{"id":"1adbf017-3ec5-4f6a-9a09-0081459b431c","type":"BasicTickFormatter"},"plot":{"id":"5396739d-6822-4629-91ce-4a69e4b3d40f","subtype":"Figure","type":"Plot"},"ticker":{"id":"ba0f9915-1ca0-4a3a-af09-ecdd6fbcde6f","type":"BasicTicker"}},"id":"2b4ed015-e022-4742-8908-1868e7f6fd6d","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[37,33,34,25,64,26,23,51,50,34,51,50,49,23,41,33,33,32,44,32,25,25,39,33,55,34,39,23,33,41,25,25,25,33,51,52,48,23,39,24,47,31,47,36,24,57,34,33,33,34,32,58,58,48,25,49,56,50,33,46,44,49,33,25,58,58,41,42,33,33,36,45,39,55,58,33,33,51,39,33,57,25,33,52,65,65,59,34,51,35,31,35,23,58,35,32,54,40,47,35,51,33,34,33,33,24,31,23,24,23,21,73,33,55,32,32,43,33,39,32,56,33,32,33,25,33,34,31,32,32,39,52,45,39,48,58,60,34,36,34,63,39,58,36,32,32,32,34,34,48,32,35,34,51,51,47,50,35,51,48,58,33,51,47,60,50,39,33,34,34,59,44,64,39,39,33,33,39,34,34,34,33,59,51,44,65,52,26,47,32,26,26,24,47,24,24,58,33,73,37,33,33,67,52,50,26,32,33,39,44,59,26,26,24,25,33,52,32,26,39,34,26,37,26,26,52,75,75,54,54,54,26,32,32,39,26,56,24,22,39,33,57,51,23,67,67,32,33,33,33,24,32,32,32,36,36,36,36,45,67,52,47,46,33,51,33,67,46,46,23,32,52,32,32,64,64,22,81,31,31,31,32,32,33,65,24,33,22,61,36,32,33,32,32,52,38,45,56,32,33,33,42,59,47,36,36,47,81,49,32,51,72,72,31,31,41,23,23,32,52,56,81,61,31,61,61,31,36,51,52,81,81,32,47,47,32,31,24,24,48,48,32,32,49,49,26,46,81,32,44,32,32,63,33,33,23,32,36,36,92,33,49,47,32,43,37,37,79,52,79,63,52,47,48,33,52,45,60,64,50,46,49,41,50,32,25,55,32,24,73,61,52,72,60,33,39,52,47,49,51,46,47,41,23,51,33,45,49,32,55,27,42,39,25,32,32,36,32,32,32,32,43,39,39,61,39,61,61,32,24,38,43,43,59,32,32,32,32,31,22,22,68,32,31,59,33,24,32,32,67,67,65,65,65,22,31,32,23,47,43,43

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f7165cf1-ef90-4a76-b39b-df9f6337576b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f7165cf1-ef90-4a76-b39b-df9f6337576b").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f7165cf1-ef90-4a76-b39b-df9f6337576b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f7165cf1-ef90-4a76-b39b-df9f6337576b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b910a684-a696-495b-966f-0bea23d8d3e1":{"roots":{"references":[{"attributes":{"data_source":{"id":"3cba8aa4-02a2-4f33-902b-4447320079d0","type":"ColumnDataSource"},"glyph":{"id":"55ec8d1b-16be-4c48-b0b2-0ed47d5ce3ce","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"ea08ea0c-aaad-4a3d-8251-cd9c54d99756","type":"Circle"},"selection_glyph":null},"id":"ebf5b0f7-29be-499b-94aa-2b48f209c8eb","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"12016155-5d28-477b-aa72-aa4f51a5eb42","type":"ColumnDataSource"},"glyph":{"id":"ba1a73fa-69c6-4092-af1a-1b8ae95c0583","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"f5c72cb0-303d-42fd-bce3-9e463cd91e84","type":"Circle"},"selection_glyph":null},"id":"86a71577-57fd-413b-a46c-b0d739886e5b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x"],"data":{"x":{"__ndarray__":"sLBMPA==","dtype":"float32","shape":[1]}}},"id":"2c53a666-692f-4f05-b235-9846843811ba","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"value":162.81674194335938}},"id":"1a372b61-90a0-4aff-aa43-7c52715c60b0","type":"Circle"},{"attributes":{"callback":null,"column_names":["x"],"data":{"x":{"__ndarray__":"L9B8vQ==","dtype":"float32","shape":[1]}}},"id":"c734e38d-018d-45a4-8485-de5f8038a903","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x"],"data":{"x":{"__ndarray__":"/ZQHvA==","dtype":"float32","shape":[1]}}},"id":"0538ab2f-14ed-4e0d-ac43-98faa81158f2","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"value":1.6876486539840698}},"id":"b8ca5e2b-efd3-49dc-86ff-148037afb320","type":"Circle"},{"attributes":{},"id":"c09c11ac-65ba-48f4-959e-c122ed4c7316","type":"ToolEvents"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"value":3.0900766849517822}},"id":"889730b7-23fb-48aa-b90b-e46bdb60765e","type":"Circle"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"value":1.7476884126663208}},"id":"16f6d3ac-64b6-4f21-83c1-3c4017e27186","type":"Circle"},{"attributes":{"callback":null,"column_names":["x"],"data":{"x":{"__ndarray__":"StnxPQ==","dtype":"float32","shape":[1]}}},"id":"dcd09ed1-2bdb-4477-b7f9-ee22ff397b20","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"b27e5c5e-73b2-440f-8cb9-15fde8038023","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"value":23.597490310668945}},"id":"79a0713b-ddb3-47ca-b7ac-e0eba7d5c062","type":"Circle"},{"attributes":{"data_source":{"id":"2c53a666-692f-4f05-b235-9846843811ba","type":"ColumnDataSource"},"glyph":{"id":"ac672c48-bfac-4612-8bab-01416bccb00c","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"79a0713b-ddb3-47ca-b7ac-e0eba7d5c062","type":"Circle"},"selection_glyph":null},"id":"d3da7bae-fdf2-48ea-9ab4-dc4f7c629d60","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"value":2.1101462841033936}},"id":"55fc7925-844b-482f-a028-dc357cf516b1","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"e772cebe-959f-4c54-b404-68bbc974cbe4","subtype":"Figure","type":"Plot"},"ticker":{"id":"cb618034-834b-463b-8a79-79e95d3aba26","type":"BasicTicker"}},"id":"b4e4dbf1-c64e-4c06-b1c6-3a42e06c2dd0","type":"Grid"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_cap":"round","li ...

# %%
sess.close
# Out:
# <bound method Session.close of <tensorflow.python.client.session.Session object at 0x116b79048>>
