# %%
import tensorflow as tf
import numpy as np
import pandas as pd

np.random.seed(777)

# %%
data = pd.read_csv('../5-0. FastText/train_corpus.txt', delimiter='\t', names=['label', 'words'])

# %%
data.head()
# Out:
#         label                                              words
# 0  __label__N  아_IC 더빙_NNG ._SF ._SY 진짜_MAG 짜증_NNG 나_NP 네요_VC...
# 1  __label__P  흠_IC ._SF .._SY 포스터_NNP 보고_JKB 초딩_NNG 영화_NNG 줄...
# 2  __label__N  너무_MAG 재_XPN 밓었_UNKNOWN 다_MAG 그래서_VV+EC 보_VX 는...
# 3  __label__N  교도소_NNG 이야기_NNG 구먼_VCP+EF ._SF ._SY 솔직히_MAG 재미...
# 4  __label__P  사이몬페그_NNP 의_JKG 익살_NNG 스런_XSA+ETM 연기_NNG 가_JKS...

# %%
x_data = np.array([str(w).strip().split(' ') for w in data.words.values])
y_data = np.array([w.replace('__label__','') for w in data.label.values])
print(x_data.shape)
print(y_data.shape)
# Out:
# (149985,)
# (149985,)

# %%
tagging_filter = []
tmp = []
for words in x_data[:1000]:
    for word in words:
        w = word.split('_')
        if len(w) > 1:
            pos1 = w[1]
            if len(pos1) > 0 and len(pos1[0]) > 0 and pos1[0] in ['N']:
                tmp.append(word)
    if len(tmp) > 0:
        tagging_filter.append(tmp)

# %%
from gensim.models import word2vec
import multiprocessing
model = word2vec.Word2Vec(
    workers     = multiprocessing.cpu_count(),
    window      = 5,      # Context window size 
    size        = 300,    # 300차원짜리 벡터스페이스에 embedding
    min_count   = 1000,     # 등장 횟수가 10 이하인 단어는 무시
    sg          = 0,      # 0이면 CBOW, 1이면 skip-gram을 사용
    batch_words = 100,    # 사전을 구축할때 한번에 읽을 단어 수
    iter        = 100     # 보통 딥러닝에서 말하는 epoch과 비슷한, 반복 횟수
    )

model.build_vocab(tagging_filter)
model.train(tagging_filter)
# 트레이닝이 완료되면 init_sims 명령으로 필요없는 메모리를 unload 시킨다.
model.init_sims(replace=True)

# %%
# model.index2word
vectors = model.syn0
vectors
# Out:
# array([[ 0.00144855, -0.0473314 , -0.02546046, ...,  0.02198311,
#         -0.04224599, -0.04596429],
#        [ 0.07621625,  0.03478968, -0.03362486, ..., -0.12553377,
#          0.03926117, -0.02914982],
#        [-0.03797698, -0.10297445,  0.01636764, ..., -0.04329744,
#         -0.01821846, -0.07366881],
#        ...,
#        [ 0.01703958,  0.02020932,  0.00251819, ...,  0.06026173,
#          0.06738231, -0.03503033],
#        [-0.06826647, -0.07715841, -0.0342704 , ...,  0.14538567,
#         -0.00164928, -0.02938739],
#        [ 0.03275493,  0.0289843 , -0.06080511, ...,  0.0112748 ,
#          0.06513945,  0.05452209]], dtype=float32)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000) 
# 여기서 중요한 것은 n_components만큼 차원을 축소함. Cartarian 좌표계로 시각화하기 위해 2차원으로 축소.
vectors_simple = tsne.fit_transform(vectors)

# %%
from bokeh.plotting import figure, show, output_notebook, output_file
from bokeh.models import HoverTool, ColumnDataSource, LabelSet
output_notebook()

source = ColumnDataSource(
    data=dict(
        x=vectors_simple.T[0],
        y=vectors_simple.T[1],
        word=model.index2word,
    )
)

labels = LabelSet(
    x='x', y='y', text='word', 
    level='glyph', 
    x_offset=5, y_offset=5, 
    source=source, 
    render_mode='canvas',
    text_font_size="3pt"
)

TOOLS = "pan,wheel_zoom,box_zoom,reset,resize"

p = figure(plot_width=700, plot_height=700, tools=[TOOLS], title="test")
p.circle('x', 'y', size=7, source=source, alpha=0.4, fill_color="red", line_color="#ff9900")

p.add_layout(labels)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="339cf54b-bfab-488b-b186-d449721ea80b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cd5019b9-f8d1-44b1-a75d-d79a288d22e2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("cd5019b9-f8d1-44b1-a75d-d79a288d22e2").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cd5019b9-f8d1-44b1-a75d-d79a288d22e2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cd5019b9-f8d1-44b1-a75d-d79a288d22e2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"91fdd49b-eb49-498d-a81f-236dd65b691b":{"roots":{"references":[{"attributes":{"formatter":{"id":"96560dc0-4a4c-4ccd-bf5b-3d7d08e2bf54","type":"BasicTickFormatter"},"plot":{"id":"03ea80ae-5fe3-4fa5-86b2-e0f676722c2c","subtype":"Figure","type":"Plot"},"ticker":{"id":"7d89923a-bf49-472e-9589-ff763ffa7d34","type":"BasicTicker"}},"id":"0b05bc75-9a41-4766-9185-4e2696121a5b","type":"LinearAxis"},{"attributes":{},"id":"6f8aecd0-7699-4f41-a182-abc785bcb87b","type":"ToolEvents"},{"attributes":{"callback":null},"id":"5ba56cf7-672e-406e-8e2f-89cf8056cd61","type":"DataRange1d"},{"attributes":{"plot":{"id":"03ea80ae-5fe3-4fa5-86b2-e0f676722c2c","subtype":"Figure","type":"Plot"}},"id":"90ce4c4e-eae2-4253-b314-b2695283e167","type":"PanTool"},{"attributes":{},"id":"54c08556-30c4-4368-83b4-c28501cd3a74","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"03ea80ae-5fe3-4fa5-86b2-e0f676722c2c","subtype":"Figure","type":"Plot"}},"id":"652ca3fd-3a04-469e-9f69-e820091659a0","type":"ResizeTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"90ce4c4e-eae2-4253-b314-b2695283e167","type":"PanTool"},{"id":"62c5c6be-7c24-4056-8418-10815a5f3d5c","type":"WheelZoomTool"},{"id":"ac9d7e36-1330-4abb-b182-ab5a16437232","type":"BoxZoomTool"},{"id":"b1592ba3-f28d-4dff-923c-45e85a976176","type":"ResetTool"},{"id":"652ca3fd-3a04-469e-9f69-e820091659a0","type":"ResizeTool"}]},"id":"f22be8a6-180f-4665-8b85-3a05744524f2","type":"Toolbar"},{"attributes":{"plot":{"id":"03ea80ae-5fe3-4fa5-86b2-e0f676722c2c","subtype":"Figure","type":"Plot"}},"id":"b1592ba3-f28d-4dff-923c-45e85a976176","type":"ResetTool"},{"attributes":{},"id":"7d89923a-bf49-472e-9589-ff763ffa7d34","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"03ea80ae-5fe3-4fa5-86b2-e0f676722c2c","subtype":"Figure","type":"Plot"},"ticker":{"id":"7d89923a-bf49-472e-9589-ff763ffa7d34","type":"BasicTicker"}},"id":"a8552d87-e2e9-41c3-8bd9-33013c1e6d68","type":"Grid"},{"attributes":{"overlay":{"id":"2a379aea-4579-412d-8d4a-4a15db20aa8e","type":"BoxAnnotation"},"plot":{"id":"03ea80ae-5fe3-4fa5-86b2-e0f676722c2c","subtype":"Figure","type":"Plot"}},"id":"ac9d7e36-1330-4abb-b182-ab5a16437232","type":"BoxZoomTool"},{"attributes":{},"id":"63ffcf8f-1582-4591-998d-42da02b6a1de","type":"BasicTicker"},{"attributes":{"plot":null,"text":"test"},"id":"6d7b188f-e87f-4801-b54d-084c9027e580","type":"Title"},{"attributes":{"plot":{"id":"03ea80ae-5fe3-4fa5-86b2-e0f676722c2c","subtype":"Figure","type":"Plot"}},"id":"62c5c6be-7c24-4056-8418-10815a5f3d5c","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"6d6f2f59-8d72-4c64-9de2-ee8e633da156","type":"ColumnDataSource"},"glyph":{"id":"6e4a9966-4bde-46f0-9a97-4f2cc4bc9d91","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"8523e223-bbf2-4ff7-88d7-4b09eb8356c5","type":"Circle"},"selection_glyph":null},"id":"12fca5bd-9c29-4548-a41a-b64611f4f9b4","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"54c08556-30c4-4368-83b4-c28501cd3a74","type":"BasicTickFormatter"},"plot":{"id":"03ea80ae-5fe3-4fa5-86b2-e0f676722c2c","subtype":"Figure","type":"Plot"},"ticker":{"id":"63ffcf8f-1582-4591-998d-42da02b6a1de","type":"BasicTicker"}},"id":"059b3f9f-fb5f-40f7-8ab0-3d93dc858bd2","type":"LinearAxis"},{"attributes":{},"id":"96560dc0-4a4c-4ccd-bf5b-3d7d08e2bf54","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"059b3f9f-fb5f-40f7-8ab0-3d93dc858bd2","type":"LinearAxis"}],"left":[{"id":"0b05bc75-9a41-4766-9185-4e2696121a5b","type":"LinearAxis"}],"plot_height":700,"plot_width":700,"renderers":[{"id":"059b3f9f-fb5f-40f7-8ab0-3d93dc858bd2","type":"LinearAxis"},{"id":"c008f552-cd69-41b9-a7ed-3e912f9d8856","type":"Grid"},{"id":"0b05bc75-9a41-4766-9185-4e2696121a5b","type":"LinearAxis"},{"id":"a8552d87-e2e9-41c3-8bd9-33013c1e6d68","type":"Grid"},{"id":"2a379aea-4579-412d-8d4a-4a15db20aa8e","type":"BoxAnnotation"},{"id":"12fca5bd-9c29-4548-a41a-b64611f4f9b4","type":"GlyphRenderer"},{"id": ...
